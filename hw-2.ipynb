# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %pylab inline

import wget
from ufal.udpipe import Model, Pipeline
import gensim

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#data = pd.read_csv("./Projects/tinkoff_ml/data/wiki-wiki/train.csv", sep='\t')
data = pd.read_csv("train.csv", sep='\t')
data.head()
# Out:
#   context_id   word  gold_sense_id  predict_sense_id  positions  \
# 0          1  замок              1               NaN        NaN
# 1          2  замок              1               NaN        NaN
# 2          3  замок              1               NaN        NaN
# 3          4  замок              1               NaN        NaN
# 4          5  замок              1               NaN        NaN
#
#                                              context
# 0  замок владимира мономаха в любече . многочисле...
# 1  шильонский замок замок шильйон ( ) , известный...
# 2  проведения архитектурно - археологических рабо...
# 3  топи с . , л . белокуров легенда о завещании м...
# 4  великий князь литовский гедимин после успешной...

# %%
data.word.unique()
# Out:
# array(['замок', 'лук', 'суда', 'бор'], dtype=object)

# %%
data.loc[:,['word', 'gold_sense_id', 'context']]\
.groupby(['word']).count()['context'].sort_values(ascending=False)
# Out:
# word
# замок    138
# суда     135
# лук      110
# бор       56
# Name: context, dtype: int64

# %%
data.loc[:,['word', 'gold_sense_id', 'context']]\
.groupby(['word', 'gold_sense_id'])['context'].count()
# Out:
# word   gold_sense_id
# бор    1                 14
#        2                 42
# замок  1                100
#        2                 38
# лук    1                 65
#        2                 45
# суда   1                100
#        2                 35
# Name: context, dtype: int64

# %% [markdown]
# # 2

# %% [markdown]
# Используем модель `udpipe_syntagrus` которая будет присваивать части речи словам

# %%
# udpipe_url = 'http://rusvectores.org/static/models/udpipe_syntagrus.model'
# modelfile = wget.download(udpipe_url)

# %%
modelfile='udpipe_syntagrus.model'
model = Model.load(modelfile)
pipeline = Pipeline(model, 'tokenize', Pipeline.DEFAULT, Pipeline.DEFAULT, 'conllu')
def tag_ud(text='Текст нужно передать функции в виде строки!'):
    processed = pipeline.process(text) # обрабатываем текст, получаем результат в формате conllu
    output = [l for l in processed.split('\n') if not l.startswith('#')] # пропускаем строки со служебной информацией
    tagged = [w.split('\t')[2].lower() + '_' + w.split('\t')[3] for w in output if w] # извлекаем из обработанного текста лемму и тэг
    tagged_propn = []
    propn  = []
    for t in tagged:
        if t.endswith('PROPN'):
            if propn:
                propn.append(t)
            else:
                propn = [t]
        else:
            if len(propn) > 1:
                name = '::'.join([x.split('_')[0] for x in propn]) + '_PROPN'
                tagged_propn.append(name)
            elif len(propn) == 1:
                tagged_propn.append(propn[0])
            tagged_propn.append(t)
            propn = []
    return tagged_propn

# %%
# %%time
data['context'] = data['context'].apply(tag_ud)
# Out:
# CPU times: user 14.2 s, sys: 29.5 ms, total: 14.3 s
# Wall time: 14.3 s

# %% [markdown]
# Удалим ненужные столбцы

# %%
data = data.drop(columns=['predict_sense_id', 'positions'])

# %%
data.head()
# Out:
#   context_id   word  gold_sense_id  \
# 0          1  замок              1
# 1          2  замок              1
# 2          3  замок              1
# 3          4  замок              1
# 4          5  замок              1
#
#                                              context
# 0  [замок_NOUN, владимир_NOUN, мономах_NOUN, в_AD...
# 1  [шильонский_ADJ, замок_NOUN, замокнуть_ADJ, ши...
# 2  [проведение_NOUN, архитектурно_ADJ, -_PUNCT, а...
# 3  [топить_NOUN, с_ADP, ._PUNCT, ,_PUNCT, литр_NO...
# 4  [великий_ADJ, князь_NOUN, литовский_ADJ, гедим...

# %% [markdown]
# Используем `taiga_upos_skipgram_300_2_2018` векторные эмбеддинги

# %%
# %%time
# model_url = 'http://rusvectores.org/static/models/rusvectores4/taiga/taiga_upos_skipgram_300_2_2018.vec.gz'
# modelfile = wget.download(model_url)
m = 'taiga_upos_skipgram_300_2_2018.vec.gz'
if m.endswith('.vec.gz'):
    model_vec = gensim.models.KeyedVectors.load_word2vec_format(m, binary=False)
elif m.endswith('.bin.gz'):
    model_vec = gensim.models.KeyedVectors.load_word2vec_format(m, binary=True)
else:
    model_vec = gensim.models.Word2Vec.load(m)
# Out:
# CPU times: user 1min 16s, sys: 591 ms, total: 1min 16s
# Wall time: 1min 16s

# %% [markdown]
# Оптимизируем

# %%
model_vec.init_sims(replace=True)

# %% [markdown]
# Представим каждый контекст в виде эмбеддинга, для этого переведем каждое слово в векторное прдеставление, сложим и усредним. Если слова нет в словаре, то мы его просто не учитываем

# %%
def context2vec(arrayOfWords):
    sentenceVector = np.zeros(300)
    sent_len = len(arrayOfWords)
    for w in arrayOfWords:
        try:
            wordVec = model_vec.word_vec(w)
            sentenceVector = np.add(sentenceVector, wordVec)
        except KeyError:
            sent_len -= 1
    sentenceVector /= sent_len
    return sentenceVector

# %%
n_data = data.loc[data['word'] == 'лук'].copy()
n_data['context'] = n_data['context'].apply(context2vec)
n_data
# Out:
#     context_id word  gold_sense_id  \
# 138        139  лук              1
# 139        140  лук              1
# 140        141  лук              1
# 141        142  лук              1
# 142        143  лук              1
# 143        144  лук              1
# 144        145  лук              1
# 145        146  лук              1
# 146        147  лук              1
# 147        148  лук              1
# 148        149  лук              1
# 149        150  лук              1
# 150        151  лук              1
# 151        152  лук              1
# 152        153  лук              1
# 153        154  лук              1
# 154        155  лук              1
# 155        156  лук              1
# 156        157  лук              1
# 157        158  лук              1
# 158        159  лук              1
# 159        160  лук              1
# 160        161  лук              1
# 161        162  лук              1
# 162        163  лук              1
# 163        164  лук              1
# 164        165  лук              1
# 165        166  лук              1
# 166        167  лук              1
# 167        168  лук              1
# ..         ...  ...            ...
# 218        219  лук              2
# 219        220  лук              2
# 220        221  лук              2
# 221        222  лук              2
# 222        223  лук              2
# 223        224  лук              2
# 224        225  лук              2
# 225        226  лук              2
# 226        227  лук              2
# 227        228  лук              2
# 228        229  лук              2
# 229        230  лук              2
# 230        231  лук              2
# 231        232  лук              2
# 232        233  лук              2
# 233        234  лук              2
# 234        235  лук              2
# 235        236  лук              2
# 236        237  лук              2
# 237        238  лук              2
# 238        239  лук              2
# 239        240  лук              2
# 240        241  лук              2
# 241        242  лук              2
# 242        243  лук              2
# 243        244  лук              2
# 244        245  лук              2
# 245        246  лук              2
# 246        247  лук              2
# 247        248  лук              2
#
#                                                context
# 138  [-0.014157257648944125, 0.03565143039399434, 0...
# 139  [0.016724002299209437, 0.026864033761861115, -...
# 140  [0.014039089417328005, 0.025787442229161767, 0...
# 141  [0.010698547778541552, 0.03715446975205422, 0....
# 142  [0.0042534099547101144, 0.02873408781563151, -...
# 143  [0.012119156075641513, 0.03438682829229427, -0...
# 144  [0.008149869014195413, 0.019619280524665907, 0...
# 145  [-0.02165675675496459, 0.01814380068646963, 0....
# 146  [-0.010786637258918388, 0.03113669203594327, 0...
# 147  [0.007892013303935528, 0.02649710145808058, 0....
# 148  [0.004967294974873463, 0.017057944607869205, 0...
# 149  [-0.0186208713417816, 0.034745949806032204, 0....
# 150  [0.002629946086288212, 0.021640201381586018, -...
# 151  [0.017493022871868952, 0.02338352251432038, -0...
# 152  [0.00474116786230857, 0.013529999617066305, 0....
# 153  [0.0092257110029459, 0.02844030378561001, -0.0...
# 154  [0.0382942697932859, 0.03876745744227347, 0.00...
# 155  [0.012408457334256835, 0.035668628976256715, 0...
# 156  [0.007854270584754307, 0.016537719197169117, -...
# 157  [0.024661829005744235, 0.02424131615507398, -0...
# 158  [0.008078195812666545, 0.0204129497597814, -0....
# 159  [0.019573908476158978, 0.037758225444704294, 0...
# 160  [0.009939420379627988, 0.019542455095534195, 0...
# 161  [0.006202838965691626, 0.01825186991719624, 0....
# 162  [0.007216077803605003, 0.027160403217567363, 0...
# 163  [0.003589153552475648, 0.03363840556882609, 0....
# 164  [-0.014436501669007595, 0.038154170923883575, ...
# 165  [0.008666898072364607, 0.02295342879369855, -0...
# 166  [0.02756085984622808, 0.035701787105534934, 0....
# 167  [0.013002383506153075, 0.01897408861127174, -0...
# ..                                                 ...
# 218  [-0.002035763622684912, -0.00539661310242743, ...
# 219  [0.005444930302632122, -4.180313503045751e-06,...
# 220  [0.010759407086879946, 0.03546945906210957, -0...
# 221  [0.016085854520925376, -0.0010534997381196887,...
# 222  [0.005322780445852664, -0.01725749333398234, -...
# 223  [0.012434232487486532, -0.00034590155029526126...
# 224  [-0.0001223712714146013, 0.00676778130645803, ...
# 225  [0.0014560710470606056, 0.0016427748406487, 0....
# 226  [0.03395352152438136, 0.002962837665108964, -0...
# 227  [0.02518653723760508, 0.001964162029325962, -0...
# 228  [-0.012672661841419098, -0.002345804386218456,...
# 229  [-0.004937208854244091, 0.003137494521070039, ...
# 230  [-0.003138506858389379, 0.012258771712367889, ...
# 231  [0.0050490961199806585, 0.005536193170795037, ...
# 232  [0.002758383401669562, 0.0010935837474082494, ...
# 233  [-0.012442767458896224, 0.01891025449955263, -...
# 234  [-0.004766458561821959, -0.0008699193287091995...
# 235  [-0.004393260724927214, -0.003444520040471671,...
# 236  [-0.022467253665949795, 0.014227659840668951, ...
# 237  [0.010759407086879946, 0.03546945906210957, -0...
# 238  [-0.0177926834772474, 0.018577011988132393, -0...
# 239  [0.01156100321024882, -0.004252024667397508, -...
# 240  [0.02216786756180227, 0.0016819274314912036, -...
# 241  [0.008672804227985796, 0.004038032097187603, -...
# 242  [0.010759407086879946, 0.03546945906210957, -0...
# 243  [-0.008565167209599166, 0.016901159228291364, ...
# 244  [0.020287885862974992, -0.0043332423229003325,...
# 245  [-0.003478944987542562, 0.003947369503222552, ...
# 246  [0.009812800723704555, 0.022830532752864417, -...
# 247  [0.0034889879697445956, -0.016988589815376882,...
#
# [110 rows x 4 columns]

# %% [markdown]
# Используем KMeans для кластрезиции, признаки – эмбеддинги предложений, посчитаем ARI

# %%
km = KMeans(n_clusters=2)
y_pred = km.fit_predict(n_data['context'].tolist())

# %%
ari = adjusted_rand_score(n_data['gold_sense_id'], y_pred)
ari
# Out:
# 0.9278721470140009

# %% [markdown]
# Повторим тот же алгоритм для других слов

# %%
def calcARIforWord(word):
    n_data = data.loc[data['word'] == word].copy()
    n_data['context'] = n_data['context'].apply(context2vec)

    km = KMeans(n_clusters=2)
    y_pred = km.fit_predict(n_data['context'].tolist())
    
    ari = adjusted_rand_score(n_data['gold_sense_id'], y_pred)
    print(ari)
    return ari

# %%
a1 = calcARIforWord('замок')
a2 = calcARIforWord('суда')
a3 = calcARIforWord('лук')
a4 = calcARIforWord('бор')
# Out:
# 0.19633906439972718
# 0.33798134638470767
# 0.9278721470140009
# 1.0

# %% [markdown]
# Среднее ARI

# %%
avg = (a1+a2+a3+a4)/4
avg
# Out:
# 0.615548139449609
